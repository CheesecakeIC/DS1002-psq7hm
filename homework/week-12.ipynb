# %% [markdown]
# <a href="https://colab.research.google.com/github/CheesecakeIC/DS1002-psq7hm/blob/main/homework/week-12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pie Chart (3 points)

# %%
# Create a pie chart from raw values

slices = [56, 66, 24, 124, 47]
labels = ["US","UK","MX","CA","JP"]

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.pie(slices)
plt.legend(labels)

# %% [markdown]
# ## Histogram (3 points)

# %%
# Create a histogram from random data

import matplotlib.pyplot as plt
import numpy as np

n = 430 + np.random.randn(3000)

# %%
plt.hist(n)
# Out:
# (array([ 21., 105., 364., 659., 797., 670., 281.,  81.,  15.,   7.]),
#  array([426.89590514, 427.5961835 , 428.29646187, 428.99674023,
#         429.69701859, 430.39729695, 431.09757531, 431.79785367,
#         432.49813204, 433.1984104 , 433.89868876]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Scatterplot with Trendline (3 points)

# %%
# Create a scatterplot with a trendline from two lists of values

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

num_points = 50
x = 5 + np.arange(num_points) + np.random.randn(num_points)
y = 10 + np.arange(num_points) + 5 * np.random.randn(num_points)

# If you want them combined into a dataframe
df = pd.DataFrame({'x': x, 'y': y})

# %%
plt.plot(df)
# Out:
# [<matplotlib.lines.Line2D at 0x790357cc1bd0>,
#  <matplotlib.lines.Line2D at 0x790357cc1c30>]
